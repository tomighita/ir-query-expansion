# %%
# !pip install faiss-cpu fast-forward-indexes==0.2.0
# Out:
# Requirement already satisfied: faiss-cpu in ./.venv/lib/python3.12/site-packages (1.8.0)
# Requirement already satisfied: fast-forward-indexes==0.2.0 in ./.venv/lib/python3.12/site-packages (0.2.0)
# Requirement already satisfied: torch>=2.0.0 in ./.venv/lib/python3.12/site-packages (from fast-forward-indexes==0.2.0) (2.3.0)
# Requirement already satisfied: numpy>=1.24.0 in ./.venv/lib/python3.12/site-packages (from fast-forward-indexes==0.2.0) (1.26.4)
# Requirement already satisfied: pandas>=2.0.3 in ./.venv/lib/python3.12/site-packages (from fast-forward-indexes==0.2.0) (2.2.2)
# Requirement already satisfied: transformers>=4.28.0 in ./.venv/lib/python3.12/site-packages (from fast-forward-indexes==0.2.0) (4.40.1)
# Requirement already satisfied: tqdm in ./.venv/lib/python3.12/site-packages (from fast-forward-indexes==0.2.0) (4.66.2)
# Requirement already satisfied: h5py>=3.0.0 in ./.venv/lib/python3.12/site-packages (from fast-forward-indexes==0.2.0) (3.11.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.12/site-packages (from pandas>=2.0.3->fast-forward-indexes==0.2.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.12/site-packages (from pandas>=2.0.3->fast-forward-indexes==0.2.0) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.12/site-packages (from pandas>=2.0.3->fast-forward-indexes==0.2.0) (2024.1)
# Requirement already satisfied: filelock in ./.venv/lib/python3.12/site-packages (from torch>=2.0.0->fast-forward-indexes==0.2.0) (3.13.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in ./.venv/lib/python3.12/site-packages (from torch>=2.0.0->fast-forward-indexes==0.2.0) (4.11.0)
# Requirement already satisfied: sympy in ./.venv/lib/python3.12/site-packages (from torch>=2.0.0->fast-forward-indexes==0.2.0) (1.12)
# Requirement already satisfied: networkx in ./.venv/lib/python3.12/site-packages (from torch>=2.0.0->fast-forward-indexes==0.2.0) (3.3)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.12/site-packages (from torch>=2.0.0->fast-forward-indexes==0.2.0) (3.1.3)
# Requirement already satisfied: fsspec in ./.venv/lib/python3.12/site-packages (from torch>=2.0.0->fast-forward-indexes==0.2.0) (2024.3.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in ./.venv/lib/python3.12/site-packages (from transformers>=4.28.0->fast-forward-indexes==0.2.0) (0.22.2)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.12/site-packages (from transformers>=4.28.0->fast-forward-indexes==0.2.0) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in ./.venv/lib/python3.12/site-packages (from transformers>=4.28.0->fast-forward-indexes==0.2.0) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in ./.venv/lib/python3.12/site-packages (from transformers>=4.28.0->fast-forward-indexes==0.2.0) (2024.4.16)
# Requirement already satisfied: requests in ./.venv/lib/python3.12/site-packages (from transformers>=4.28.0->fast-forward-indexes==0.2.0) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in ./.venv/lib/python3.12/site-packages (from transformers>=4.28.0->fast-forward-indexes==0.2.0) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in ./.venv/lib/python3.12/site-packages (from transformers>=4.28.0->fast-forward-indexes==0.2.0) (0.4.3)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=2.0.3->fast-forward-indexes==0.2.0) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.12/site-packages (from jinja2->torch>=2.0.0->fast-forward-indexes==0.2.0) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.12/site-packages (from requests->transformers>=4.28.0->fast-forward-indexes==0.2.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.12/site-packages (from requests->transformers>=4.28.0->fast-forward-indexes==0.2.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.12/site-packages (from requests->transformers>=4.28.0->fast-forward-indexes==0.2.0) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.12/site-packages (from requests->transformers>=4.28.0->fast-forward-indexes==0.2.0) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in ./.venv/lib/python3.12/site-packages (from sympy->torch>=2.0.0->fast-forward-indexes==0.2.0) (1.3.0)

# %%
import prebuilt_index_info
from urllib.request import urlretrieve
import tarfile 
import faiss
import os
from pathlib import Path
from fast_forward import OnDiskIndex
import shutil

DIR_NAME = 'indexes'
REMOVE_AFTER_DOWNLOAD = True
INTERESTING_DATASETS = ['beir-v1.0.0-trec-covid.contriever','beir-v1.0.0-arguana.contriever', 'beir-v1.0.0-cqadupstack-programmers.contriever-msmarco', 'beir-v1.0.0-cqadupstack-android.contriever','beir-v1.0.0-nfcorpus.contriever-msmarco']

for dataset_name in prebuilt_index_info.FAISS_INDEX_INFO_BEIR.keys():
    # placeholder
    if dataset_name not in INTERESTING_DATASETS:
        continue
        
    dataset_url = prebuilt_index_info.FAISS_INDEX_INFO_BEIR[dataset_name]['urls'][0]
    faiss_idx_filename = prebuilt_index_info.FAISS_INDEX_INFO_BEIR[dataset_name]['filename']
    faiss_dir_name = faiss_idx_filename[:-7]
    faiss_dir_full_path = os.path.join(DIR_NAME, faiss_dir_name)
    
    if not os.path.exists(Path(DIR_NAME, faiss_dir_name + ".h5")) and not os.path.exists(faiss_dir_full_path):
        print(f'Downloading archive: {faiss_idx_filename}')
        # Download archive
        urlretrieve(dataset_url, faiss_idx_filename)
        # Un-archive the .tar.gz
        archive_faiss = tarfile.open(faiss_idx_filename)  
        archive_faiss.extractall(DIR_NAME)
        archive_faiss.close()
        # Delete archive
        os.remove(faiss_idx_filename)
    
        print("Indexing...")    
        index = faiss.read_index(os.path.join(DIR_NAME, faiss_dir_name, "index"))
        with open(os.path.join(DIR_NAME, faiss_dir_name, "docid")) as fp:
            docids = list(fp.read().splitlines())
        
        vectors = index.reconstruct_n(0, len(docids))
        OnDiskIndex(Path(DIR_NAME, faiss_dir_name + ".h5"), 768, max_id_length = 60).add(vectors, doc_ids=docids)
    
        print(f'Finished indexing {dataset_name}.')
        
    if os.path.exists(faiss_dir_full_path) and REMOVE_AFTER_DOWNLOAD:
        shutil.rmtree(os.path.join(DIR_NAME, faiss_dir_name))

# %%
pip install python-terrier==0.10.0 fast-forward-indexes==0.2.0

# %%
import pyterrier as pt

if not pt.started():
    pt.init(
        tqdm="notebook",
        boot_packages=["com.github.terrierteam:terrier-prf:-SNAPSHOT"]
    )
# Out:
# PyTerrier 0.10.0 has loaded Terrier 5.9 (built by craigm on 2024-05-02 17:40) and terrier-helper 0.0.8
#
# No etc/terrier.properties, using terrier.default.properties for bootstrap configuration.

# %%
DATASET_NAME = 'irds:beir/msmarco'
TESTSET_NAME = 'irds:msmarco-passage/trec-dl-hard'
BM25_INDEX_PATH = 'indices/msmarco'
INDEX_PATH = 'indexes/ff_msmarco-v1-passage.tct_colbert.h5'
FIELDS = ['text','title']

# %%
dataset = pt.get_dataset(DATASET_NAME)

# %%
from pathlib import Path

idx_path = Path(BM25_INDEX_PATH).absolute()

index_ref = pt.index.IterDictIndexer(
    str(idx_path),
    blocks=True,
    meta={'docno': 60},
    # stopwords=None,
    # stemmer=None,
).index(dataset.get_corpus_iter(), fields=["text"])
# Out:
# beir/msmarco documents:   0%|          | 0/8841823 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 11
#       1 from pathlib import Path
#       3 idx_path = Path(BM25_INDEX_PATH).absolute()
#       5 index_ref = pt.index.IterDictIndexer(
#       6     str(idx_path),
#       7     blocks=True,
#       8     meta={'docno': 60},
#       9     # stopwords=None,
#      10     # stemmer=None,
# ---> 11 ).index(dataset.get_corpus_iter(), fields=["text"])
#
# File ~/Scoala/Facultate/University-Courses/RP/.venv/lib/python3.12/site-packages/pyterrier/index.py:1011, in _IterDictIndexer_fifo.index(self, it, fields, meta, meta_lengths)
#    1008     if meta_lengths is not None:
#    1009         self.meta = {zip(meta, meta_lengths)}
# -> 1011 self._setup(fields, self.meta, None)
#    1013 os.makedirs(self.index_dir, exist_ok=True) # ParallelIndexer expects the directory to exist
#    1015 Indexer, Merger = self.indexerAndMergerClasses()
#
# File ~/Scoala/Facultate/University-Courses/RP/.venv/lib/python3.12/site-packages/pyterrier/index.py:850, in _BaseIterDictIndexer._setup(self, fields, meta, meta_lengths)
#     840 def _setup(self, fields, meta, meta_lengths):
#     841     """
#     842     Index the specified iter of dicts with the (optional) specified fields
#     843
#    (...)
#     848         meta_lengths(list[int]): deprecated
#     849     """
# --> 850     self.checkIndexExists()
#     851     if isinstance(meta, dict):
#     852         self.meta = meta
#
# File ~/Scoala/Facultate/University-Courses/RP/.venv/lib/python3.12/site-packages/pyterrier/index.py:520, in TerrierIndexer.checkIndexExists(self)
#     518 if os.path.isfile(self.path):
#     519     if not self.overwrite:
# --> 520         raise ValueError("Index already exists at " + self.path)
#     521 if self.index_called:
#     522     raise Exception("Index method can be called only once")
#
# ValueError: Index already exists at /Users/tomighita/Scoala/Facultate/University-Courses/RP/indices/msmarco/data.properties

# %%
from pyterrier.measures import RR, nDCG, MAP

index = pt.IndexFactory.of(str(idx_path))

bm25 = pt.BatchRetrieve(index, wmodel="BM25")
rm3 = pt.rewrite.RM3(index)
testset = pt.get_dataset(TESTSET_NAME)
pt.Experiment(
    [bm25],
    testset.get_topics('text'),
    testset.get_qrels(),
    eval_metrics=[RR @ 10, nDCG @ 10, MAP @ 100],
)
# Out:
#        name     RR@10   nDCG@10    AP@100
# 0  BR(BM25)  0.519579  0.274333  0.164399

# %%
from fast_forward.encoder import TCTColBERTQueryEncoder, TCTColBERTDocumentEncoder
import torch

q_encoder = TCTColBERTQueryEncoder("castorini/tct_colbert-msmarco")
d_encoder = TCTColBERTDocumentEncoder(
    "castorini/tct_colbert-msmarco",
    device="cuda:0" if torch.cuda.is_available() else "cpu",
)
q_encoder(["Test query 1", "Test query 2"])
# Out:
# array([[-0.0380525 ,  0.01848466,  0.05137944, ..., -0.04796502,
#          0.00918062, -0.03880693],
#        [-0.06809073,  0.02582865,  0.09803923, ..., -0.09031374,
#          0.00014139, -0.06282968]], dtype=float32)

# %%
from fast_forward import OnDiskIndex, Mode

ff_index = OnDiskIndex.load(
    Path(INDEX_PATH), query_encoder=q_encoder, mode=Mode.MAXP
)
# ff_index = ff_index.to_memory()
# Out:
#   0%|          | 0/8841823 [00:00<?, ?it/s]
#   1%|          | 72027/8841823 [00:00<00:13, 633902.04it/s]
#   2%|▏         | 198863/8841823 [00:00<00:11, 730233.56it/s]
#   4%|▍         | 351779/8841823 [00:00<00:08, 1026211.90it/s]
#   5%|▌         | 460627/8841823 [00:00<00:09, 850351.59it/s]
#   6%|▋         | 561880/8841823 [00:00<00:11, 717953.66it/s]
#   8%|▊         | 699051/8841823 [00:00<00:09, 872462.35it/s]
#   9%|▉         | 814865/8841823 [00:01<00:10, 734660.43it/s]
#  11%|█         | 982380/8841823 [00:01<00:08, 944561.55it/s]
#  13%|█▎        | 1118494/8841823 [00:01<00:07, 1045263.80it/s]
#  14%|█▍        | 1236612/8841823 [00:01<00:09, 813766.35it/s]
#  16%|█▌        | 1373752/8841823 [00:01<00:07, 934475.44it/s]
#  17%|█▋        | 1483508/8841823 [00:01<00:08, 886229.47it/s]
#  18%|█▊        | 1583480/8841823 [00:02<00:12, 602163.27it/s]
#  20%|██        | 1775626/8841823 [00:02<00:08, 841413.68it/s]
#  22%|██▏       | 1957952/8841823 [00:02<00:06, 1043439.32it/s]
#  24%|██▎       | 2092051/8841823 [00:02<00:07, 853071.05it/s]
#  26%|██▌       | 2257836/8841823 [00:02<00:06, 1013601.73it/s]
#  27%|██▋       | 2421636/8841823 [00:02<00:05, 1152065.28it/s]
#  29%|██▉       | 2582355/8841823 [00:02<00:04, 1261553.78it/s]
#  31%|███       | 2727466/8841823 [00:03<00:06, 930870.45it/s]
#  32%|███▏      | 2845815/8841823 [00:03<00:06, 931167.05it/s]
#  34%|███▍      | 3035030/8841823 [00:03<00:05, 1140763.14it/s]
#  36%|███▋      | 3222337/8841823 [00:03<00:04, 1314726.74it/s]
#  39%|███▊      | 3407871/8841823 [00:03<00:03, 1451701.76it/s]
#  40%|████      | 3568693/8841823 [00:03<00:05, 989682.63it/s]
#  42%|████▏     | 3743120/8841823 [00:03<00:04, 1141378.73it/s]
#  44%|████▍     | 3918898/8841823 [00:03<00:03, 1278904.18it/s]
#  46%|████▋     | 4093185/8841823 [00:04<00:03, 1391035.09it/s]
#  48%|████▊     | 4266917/8841823 [00:04<00:03, 1479902.17it/s]
#  50%|█████     | 4430425/8841823 [00:04<00:04, 931469.90it/s]
#  52%|█████▏    | 4599004/8841823 [00:04<00:03, 1074789.95it/s]
#  54%|█████▍    | 4765779/8841823 [00:04<00:03, 1201391.86it/s]
#  56%|█████▌    | 4931281/8841823 [00:04<00:02, 1307408.89it/s]
#  58%|█████▊    | 5095667/8841823 [00:04<00:02, 1391624.42it/s]
#  59%|█████▉    | 5255521/8841823 [00:04<00:02, 1446118.79it/s]
#  61%|██████▏   | 5416957/8841823 [00:05<00:02, 1492113.76it/s]
#  63%|██████▎   | 5576703/8841823 [00:05<00:02, 1521694.28it/s]
#  65%|██████▍   | 5735847/8841823 [00:05<00:04, 751409.28it/s]
#  67%|██████▋   | 5925818/8841823 [00:05<00:03, 942297.03it/s]
#  69%|██████▉   | 6116506/8841823 [00:05<00:02, 1127403.06it/s]
#  71%|███████▏  | 6305121/8841823 [00:05<00:01, 1290650.03it/s]
#  73%|███████▎  | 6488991/8841823 [00:06<00:01, 1419230.50it/s]
#  75%|███████▌  | 6674467/8841823 [00:06<00:01, 1528649.12it/s]
#  78%|███████▊  | 6857641/8841823 [00:06<00:01, 1608715.27it/s]
#  80%|███████▉  | 7039973/8841823 [00:06<00:01, 1667517.46it/s]
#  82%|████████▏ | 7219223/8841823 [00:06<00:01, 886132.08it/s]
#  84%|████████▎ | 7400764/8841823 [00:06<00:01, 1046877.20it/s]
#  86%|████████▌ | 7575576/8841823 [00:06<00:01, 1185824.07it/s]
#  88%|████████▊ | 7750819/8841823 [00:07<00:00, 1310825.50it/s]
#  90%|████████▉ | 7926292/8841823 [00:07<00:00, 1417197.69it/s]
#  92%|█████████▏| 8099685/8841823 [00:07<00:00, 1497971.30it/s]
#  94%|█████████▎| 8268578/8841823 [00:07<00:00, 1538855.59it/s]
#  95%|█████████▌| 8439545/8841823 [00:07<00:00, 1585787.43it/s]
#  97%|█████████▋| 8611001/8841823 [00:07<00:00, 1622078.38it/s]
# 100%|██████████| 8841823/8841823 [00:07<00:00, 1142450.18it/s]

# %%
from fast_forward.util.pyterrier import FFScore
from fast_forward.util.pyterrier import FFInterpolate

ff_score = FFScore(ff_index)
candidates = (bm25 % 5)(testset.get_topics('text')) # Get the candidates
re_ranked = ff_score(candidates)
ff_int = FFInterpolate(alpha=0.1)
ff_int(re_ranked)
# Out:
#          qid    docno                              query      score
# 0    1108939  4069373  what slows down the flow of blood  65.616525
# 1    1108939  4744533  what slows down the flow of blood  65.808511
# 2    1108939  7454708  what slows down the flow of blood  65.389526
# 3    1108939  7724054  what slows down the flow of blood  63.709970
# 4    1108939   841975  what slows down the flow of blood  65.060473
# ..       ...      ...                                ...        ...
# 245    88495  6579243                   causes of stroke  64.547018
# 246    88495  7088443                   causes of stroke  63.961109
# 247    88495  7112879                   causes of stroke  64.208614
# 248    88495   841692                   causes of stroke  65.046491
# 249    88495   841696                   causes of stroke  65.095718
#
# [250 rows x 4 columns]

# %%
import re

def _remove_pollution(q) -> str:
    q_old = q["query"].replace('applypipeline:off', '')
    return q["query_1"] + " " + re.sub(r'\^(\d)+\.(\d)+', '', q_old)

def _return_to_init_query(q) -> str:
    return q["query_2"]

pipeline = bm25 % 5 >> rm3 >> pt.apply.query(_remove_pollution) >> bm25 % 1000

pipeline(testset.get_topics('text'))
# Out:
#            qid    docid    docno  rank      score  \
# 0      1049519  6921021  6921021     0  57.538152
# 1      1049519  8279758  8279758     1  43.846931
# 2      1049519  6921018  6921018     2  43.068182
# 3      1049519  1316185  1316185     3  40.086729
# 4      1049519  5355117  5355117     4  37.014415
# ...        ...      ...      ...   ...        ...
# 49995   966413  7506828  7506828   995  21.800356
# 49996   966413  2089398  2089398   996  21.799519
# 49997   966413  1481171  1481171   997  21.798988
# 49998   966413  8054508  8054508   998  21.792947
# 49999   966413  4583591  4583591   999  21.789690
#
#                                                   query_1  \
# 0              who said no one can make you feel inferior
# 1              who said no one can make you feel inferior
# 2              who said no one can make you feel inferior
# 3              who said no one can make you feel inferior
# 4              who said no one can make you feel inferior
# ...                                                   ...
# 49995  where are the benefits of cinnamon as a supplement
# 49996  where are the benefits of cinnamon as a supplement
# 49997  where are the benefits of cinnamon as a supplement
# 49998  where are the benefits of cinnamon as a supplement
# 49999  where are the benefits of cinnamon as a supplement
#
#                                                                                                                                                                                                                           query_0  \
# 0      applypipeline:off insecur^0.018691590 person^0.019976636 feel^0.257943928 ly^0.018691590 complex^0.040654209 inferior^0.243691593 can^0.150000006 who^0.179906547 accomplish^0.018691590 peopl^0.027453272 sai^0.024299067
# 1      applypipeline:off insecur^0.018691590 person^0.019976636 feel^0.257943928 ly^0.018691590 complex^0.040654209 inferior^0.243691593 can^0.150000006 who^0.179906547 accomplish^0.018691590 peopl^0.027453272 sai^0.024299067
# 2      applypipeline:off insecur^0.018691590 person^0.019976636 feel^0.257943928 ly^0.018691590 complex^0.040654209 inferior^0.243691593 can^0.150000006 who^0.179906547 accomplish^0.018691590 peopl^0.027453272 sai^0.024299067
# 3      applypipeline:off insecur^0.018691590 person^0.019976636 feel^0.257943928 ly^0.018691590 complex^0.040654209 inferior^0.243691593 can^0.150000006 who^0.179906547 accomplish^0.018691590 peopl^0.027453272 sai^0.024299067
# 4      applypipeline:off insecur^0.018691590 person^0.019976636 feel^0.257943928 ly^0.018691590 complex^0.040654209 inferior^0.243691593 can^0.150000006 who^0.179906547 accomplish^0.018691590 peopl^0.027453272 sai^0.024299067
# ...                                                                                                                                                                                                                           ...
# 49995             applypipeline:off lower^0.018758623 help^0.018758623 blood^0.026206898 benefit^0.265379339 sugar^0.026206898 studi^0.018758623 health^0.056000002 cinnamon^0.326896548 supplement^0.228137955 honei^0.014896553
# 49996             applypipeline:off lower^0.018758623 help^0.018758623 blood^0.026206898 benefit^0.265379339 sugar^0.026206898 studi^0.018758623 health^0.056000002 cinnamon^0.326896548 supplement^0.228137955 honei^0.014896553
# 49997             applypipeline:off lower^0.018758623 help^0.018758623 blood^0.026206898 benefit^0.265379339 sugar^0.026206898 studi^0.018758623 health^0.056000002 cinnamon^0.326896548 supplement^0.228137955 honei^0.014896553
# 49998             applypipeline:off lower^0.018758623 help^0.018758623 blood^0.026206898 benefit^0.265379339 sugar^0.026206898 studi^0.018758623 health^0.056000002 cinnamon^0.326896548 supplement^0.228137955 honei^0.014896553
# 49999             applypipeline:off lower^0.018758623 help^0.018758623 blood^0.026206898 benefit^0.265379339 sugar^0.026206898 studi^0.018758623 health^0.056000002 cinnamon^0.326896548 supplement^0.228137955 honei^0.014896553
#
#                                                                                                                            query
# 0               who said no one can make you feel inferior  insecur person feel ly complex inferior can who accomplish peopl sai
# 1               who said no one can make you feel inferior  insecur person feel ly complex inferior can who accomplish peopl sai
# 2               who said no one can make you feel inferior  insecur person feel ly complex inferior can who accomplish peopl sai
# 3               who said no one can make you feel inferior  insecur person feel ly complex inferior can who accomplish peopl sai
# 4               who said no one can make you feel inferior  insecur person feel ly complex inferior can who accomplish peopl sai
# ...                                                                                                                          ...
# 49995  where are the benefits of cinnamon as a supplement  lower help blood benefit sugar studi health cinnamon supplement honei
# 49996  where are the benefits of cinnamon as a supplement  lower help blood benefit sugar studi health cinnamon supplement honei
# 49997  where are the benefits of cinnamon as a supplement  lower help blood benefit sugar studi health cinnamon supplement honei
# 49998  where are the benefits of cinnamon as a supplement  lower help blood benefit sugar studi health cinnamon supplement honei
# 49999  where are the benefits of cinnamon as a supplement  lower help blood benefit sugar studi health cinnamon supplement honei
#
# [50000 rows x 8 columns]

# %%
exp_results_dir = Path("exp_results")
exp_results_dir.mkdir(exist_ok=True)

result = pt.Experiment(
    [
        bm25,
        bm25 % 5 >> rm3 >> bm25,
        bm25 % 1 >> rm3 >> bm25,
        bm25 % 1000 >> ff_score >> ff_int,
        pipeline >> ff_score >> ff_int,
        pipeline >> pt.apply.query(_return_to_init_query) >> ff_score >> ff_int
    ],
    testset.get_topics('text'),
    testset.get_qrels(),
    eval_metrics=[RR(rel=2) @ 10, nDCG @ 10, MAP @ 100],
    names=[
        "BM25",
        "RM3",
        "RM3 % 1",
        "BM25 >> FF",
        "BM25 >> RM3 >> FF",
        "BM25 >> RM3 >> FF (og q)"
    ]
)
result
# Out:
#                        name  RR(rel=2)@10   nDCG@10    AP@100
# 0                      BM25      0.415056  0.274333  0.164399
# 1                       RM3      0.389222  0.270870  0.178831
# 2                   RM3 % 1      0.414468  0.292751  0.184966
# 3                BM25 >> FF      0.551000  0.390350  0.238197
# 4         BM25 >> RM3 >> FF      0.395278  0.285421  0.180305
# 5  BM25 >> RM3 >> FF (og q)      0.431389  0.327697  0.204134

# %%
import csv   

name_to_csv = {
    "BM25": "results/BM25.csv",
    "RM3": "results/RM3.csv",
    "RM3 % 1": "results/RM3_1.csv",
    "BM25 >> FF": "results/BM25_FF.csv",
    "BM25 >> RM3 >> FF": "results/BM25_RM3_FF.csv",
}

for index, row in result.iterrows():
    with open(name_to_csv[row['name']], 'a') as f:
        writer = csv.writer(f)
        changed_row = [TESTSET_NAME, row.iloc[1], row.iloc[2], row.iloc[3]]
        writer.writerow(changed_row)
