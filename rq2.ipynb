# %%
pip install python-terrier==0.10.0 fast-forward-indexes==0.2.0
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: python-terrier==0.10.0 in ./.venv/lib/python3.12/site-packages (0.10.0)
# Requirement already satisfied: fast-forward-indexes==0.2.0 in ./.venv/lib/python3.12/site-packages (0.2.0)
# Requirement already satisfied: numpy in ./.venv/lib/python3.12/site-packages (from python-terrier==0.10.0) (1.26.4)
# Requirement already satisfied: pandas in ./.venv/lib/python3.12/site-packages (from python-terrier==0.10.0) (2.2.2)
# Requirement already satisfied: wget in ./.venv/lib/python3.12/site-packages (from python-terrier==0.10.0) (3.2)
# Requirement already satisfied: tqdm in ./.venv/lib/python3.12/site-packages (from python-terrier==0.10.0) (4.66.2)
# Requirement already satisfied: pyjnius>=1.4.2 in ./.venv/lib/python3.12/site-packages (from python-terrier==0.10.0) (1.6.1)
# Requirement already satisfied: matchpy in ./.venv/lib/python3.12/site-packages (from python-terrier==0.10.0) (0.5.5)
# Requirement already satisfied: scikit-learn in ./.venv/lib/python3.12/site-packages (from python-terrier==0.10.0) (1.4.2)
# Requirement already satisfied: deprecated in ./.venv/lib/python3.12/site-packages (from python-terrier==0.10.0) (1.2.14)
# Requirement already satisfied: chest in ./.venv/lib/python3.12/site-packages (from python-terrier==0.10.0) (0.2.3)
# Requirement already satisfied: scipy in ./.venv/lib/python3.12/site-packages (from python-terrier==0.10.0) (1.13.0)
# Requirement already satisfied: requests in ./.venv/lib/python3.12/site-packages (from python-terrier==0.10.0) (2.31.0)
# Requirement already satisfied: joblib in ./.venv/lib/python3.12/site-packages (from python-terrier==0.10.0) (1.4.0)
# Requirement already satisfied: nptyping==1.4.4 in ./.venv/lib/python3.12/site-packages (from python-terrier==0.10.0) (1.4.4)
# Requirement already satisfied: more-itertools in ./.venv/lib/python3.12/site-packages (from python-terrier==0.10.0) (10.2.0)
# Requirement already satisfied: ir-datasets>=0.3.2 in ./.venv/lib/python3.12/site-packages (from python-terrier==0.10.0) (0.5.6)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.12/site-packages (from python-terrier==0.10.0) (3.1.3)
# Requirement already satisfied: statsmodels in ./.venv/lib/python3.12/site-packages (from python-terrier==0.10.0) (0.14.2)
# Requirement already satisfied: ir-measures>=0.3.1 in ./.venv/lib/python3.12/site-packages (from python-terrier==0.10.0) (0.3.3)
# Requirement already satisfied: dill in ./.venv/lib/python3.12/site-packages (from python-terrier==0.10.0) (0.3.8)
# Requirement already satisfied: pytrec-eval-terrier>=0.5.3 in ./.venv/lib/python3.12/site-packages (from python-terrier==0.10.0) (0.5.6)
# Requirement already satisfied: torch>=2.0.0 in ./.venv/lib/python3.12/site-packages (from fast-forward-indexes==0.2.0) (2.3.0)
# Requirement already satisfied: transformers>=4.28.0 in ./.venv/lib/python3.12/site-packages (from fast-forward-indexes==0.2.0) (4.40.1)
# Requirement already satisfied: h5py>=3.0.0 in ./.venv/lib/python3.12/site-packages (from fast-forward-indexes==0.2.0) (3.11.0)
# Requirement already satisfied: typish>=1.7.0 in ./.venv/lib/python3.12/site-packages (from nptyping==1.4.4->python-terrier==0.10.0) (1.9.3)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in ./.venv/lib/python3.12/site-packages (from ir-datasets>=0.3.2->python-terrier==0.10.0) (4.12.3)
# Requirement already satisfied: inscriptis>=2.2.0 in ./.venv/lib/python3.12/site-packages (from ir-datasets>=0.3.2->python-terrier==0.10.0) (2.5.0)
# Requirement already satisfied: lxml>=4.5.2 in ./.venv/lib/python3.12/site-packages (from ir-datasets>=0.3.2->python-terrier==0.10.0) (5.2.1)
# Requirement already satisfied: pyyaml>=5.3.1 in ./.venv/lib/python3.12/site-packages (from ir-datasets>=0.3.2->python-terrier==0.10.0) (6.0.1)
# Requirement already satisfied: trec-car-tools>=2.5.4 in ./.venv/lib/python3.12/site-packages (from ir-datasets>=0.3.2->python-terrier==0.10.0) (2.6)
# Requirement already satisfied: lz4>=3.1.10 in ./.venv/lib/python3.12/site-packages (from ir-datasets>=0.3.2->python-terrier==0.10.0) (4.3.3)
# Requirement already satisfied: warc3-wet>=0.2.3 in ./.venv/lib/python3.12/site-packages (from ir-datasets>=0.3.2->python-terrier==0.10.0) (0.2.3)
# Requirement already satisfied: warc3-wet-clueweb09>=0.2.5 in ./.venv/lib/python3.12/site-packages (from ir-datasets>=0.3.2->python-terrier==0.10.0) (0.2.5)
# Requirement already satisfied: zlib-state>=0.1.3 in ./.venv/lib/python3.12/site-packages (from ir-datasets>=0.3.2->python-terrier==0.10.0) (0.1.6)
# Requirement already satisfied: ijson>=3.1.3 in ./.venv/lib/python3.12/site-packages (from ir-datasets>=0.3.2->python-terrier==0.10.0) (3.2.3)
# Requirement already satisfied: pyautocorpus>=0.1.1 in ./.venv/lib/python3.12/site-packages (from ir-datasets>=0.3.2->python-terrier==0.10.0) (0.1.12)
# Requirement already satisfied: unlzw3>=0.2.1 in ./.venv/lib/python3.12/site-packages (from ir-datasets>=0.3.2->python-terrier==0.10.0) (0.2.2)
# Requirement already satisfied: cwl-eval>=1.0.10 in ./.venv/lib/python3.12/site-packages (from ir-measures>=0.3.1->python-terrier==0.10.0) (1.0.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.12/site-packages (from pandas->python-terrier==0.10.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.12/site-packages (from pandas->python-terrier==0.10.0) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.12/site-packages (from pandas->python-terrier==0.10.0) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.12/site-packages (from requests->python-terrier==0.10.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.12/site-packages (from requests->python-terrier==0.10.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.12/site-packages (from requests->python-terrier==0.10.0) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.12/site-packages (from requests->python-terrier==0.10.0) (2024.2.2)
# Requirement already satisfied: filelock in ./.venv/lib/python3.12/site-packages (from torch>=2.0.0->fast-forward-indexes==0.2.0) (3.13.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in ./.venv/lib/python3.12/site-packages (from torch>=2.0.0->fast-forward-indexes==0.2.0) (4.11.0)
# Requirement already satisfied: sympy in ./.venv/lib/python3.12/site-packages (from torch>=2.0.0->fast-forward-indexes==0.2.0) (1.12)
# Requirement already satisfied: networkx in ./.venv/lib/python3.12/site-packages (from torch>=2.0.0->fast-forward-indexes==0.2.0) (3.3)
# Requirement already satisfied: fsspec in ./.venv/lib/python3.12/site-packages (from torch>=2.0.0->fast-forward-indexes==0.2.0) (2024.3.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in ./.venv/lib/python3.12/site-packages (from transformers>=4.28.0->fast-forward-indexes==0.2.0) (0.22.2)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.12/site-packages (from transformers>=4.28.0->fast-forward-indexes==0.2.0) (24.0)
# Requirement already satisfied: regex!=2019.12.17 in ./.venv/lib/python3.12/site-packages (from transformers>=4.28.0->fast-forward-indexes==0.2.0) (2024.4.16)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in ./.venv/lib/python3.12/site-packages (from transformers>=4.28.0->fast-forward-indexes==0.2.0) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in ./.venv/lib/python3.12/site-packages (from transformers>=4.28.0->fast-forward-indexes==0.2.0) (0.4.3)
# Requirement already satisfied: heapdict in ./.venv/lib/python3.12/site-packages (from chest->python-terrier==0.10.0) (1.0.1)
# Requirement already satisfied: wrapt<2,>=1.10 in ./.venv/lib/python3.12/site-packages (from deprecated->python-terrier==0.10.0) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.12/site-packages (from jinja2->python-terrier==0.10.0) (2.1.5)
# Requirement already satisfied: multiset<3.0,>=2.0 in ./.venv/lib/python3.12/site-packages (from matchpy->python-terrier==0.10.0) (2.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./.venv/lib/python3.12/site-packages (from scikit-learn->python-terrier==0.10.0) (3.4.0)
# Requirement already satisfied: patsy>=0.5.6 in ./.venv/lib/python3.12/site-packages (from statsmodels->python-terrier==0.10.0) (0.5.6)
# Requirement already satisfied: soupsieve>1.2 in ./.venv/lib/python3.12/site-packages (from beautifulsoup4>=4.4.1->ir-datasets>=0.3.2->python-terrier==0.10.0) (2.5)
# Requirement already satisfied: six in ./.venv/lib/python3.12/site-packages (from patsy>=0.5.6->statsmodels->python-terrier==0.10.0) (1.16.0)
# Requirement already satisfied: cbor>=1.0.0 in ./.venv/lib/python3.12/site-packages (from trec-car-tools>=2.5.4->ir-datasets>=0.3.2->python-terrier==0.10.0) (1.0.0)
# Requirement already satisfied: mpmath>=0.19 in ./.venv/lib/python3.12/site-packages (from sympy->torch>=2.0.0->fast-forward-indexes==0.2.0) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyterrier as pt

if not pt.started():
    pt.init(
        tqdm="notebook",
        boot_packages=["com.github.terrierteam:terrier-prf:-SNAPSHOT"]
    )
# Out:
# PyTerrier 0.10.0 has loaded Terrier 5.9 (built by craigm on 2024-05-02 17:40) and terrier-helper 0.0.8
#
# No etc/terrier.properties, using terrier.default.properties for bootstrap configuration.

# %%
DATASET_NAME = "beir/webis-touche2020/v2"
TESTSET_NAME = "beir/webis-touche2020/v2"
BM25_INDEX_PATH = 'indices/webis_idx_blocks'
INDEX_PATH = 'indexes/irds:beir_webis-touche2020_v2.h5'
FIELDS = ["text"]

# %%
import ir_datasets
dataset = pt.get_dataset('irds:' + DATASET_NAME)
ir_ds = ir_datasets.load(DATASET_NAME)

# %%
from pathlib import Path

idx_path = Path(BM25_INDEX_PATH).absolute()

index_ref = pt.index.IterDictIndexer(
    str(idx_path),
    blocks=True,
    meta={'docno': ir_ds.docs_metadata()['fields']['doc_id']['max_len'] },
    # stopwords=None,
    # stemmer=None,
).index(dataset.get_corpus_iter(), fields=FIELDS)
index_ref = index_ref.to_memory()
# Out:
# beir/webis-touche2020/v2 documents:   0%|          | 0/382545 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[71], line 11
#       1 from pathlib import Path
#       3 idx_path = Path(BM25_INDEX_PATH).absolute()
#       5 index_ref = pt.index.IterDictIndexer(
#       6     str(idx_path),
#       7     blocks=True,
#       8     meta={'docno': ir_ds.docs_metadata()['fields']['doc_id']['max_len'] },
#       9     # stopwords=None,
#      10     # stemmer=None,
# ---> 11 ).index(dataset.get_corpus_iter(), fields=FIELDS)
#      12 index_ref = index_ref.to_memory()
#
# File ~/Scoala/Facultate/University-Courses/RP/.venv/lib/python3.12/site-packages/pyterrier/index.py:1011, in _IterDictIndexer_fifo.index(self, it, fields, meta, meta_lengths)
#    1008     if meta_lengths is not None:
#    1009         self.meta = {zip(meta, meta_lengths)}
# -> 1011 self._setup(fields, self.meta, None)
#    1013 os.makedirs(self.index_dir, exist_ok=True) # ParallelIndexer expects the directory to exist
#    1015 Indexer, Merger = self.indexerAndMergerClasses()
#
# File ~/Scoala/Facultate/University-Courses/RP/.venv/lib/python3.12/site-packages/pyterrier/index.py:850, in _BaseIterDictIndexer._setup(self, fields, meta, meta_lengths)
#     840 def _setup(self, fields, meta, meta_lengths):
#     841     """
#     842     Index the specified iter of dicts with the (optional) specified fields
#     843
#    (...)
#     848         meta_lengths(list[int]): deprecated
#     849     """
# --> 850     self.checkIndexExists()
#     851     if isinstance(meta, dict):
#     852         self.meta = meta
#
# File ~/Scoala/Facultate/University-Courses/RP/.venv/lib/python3.12/site-packages/pyterrier/index.py:520, in TerrierIndexer.checkIndexExists(self)
#     518 if os.path.isfile(self.path):
#     519     if not self.overwrite:
# --> 520         raise ValueError("Index already exists at " + self.path)
#     521 if self.index_called:
#     522     raise Exception("Index method can be called only once")
#
# ValueError: Index already exists at /Users/tomighita/Scoala/Facultate/University-Courses/RP/indices/webis_idx_blocks/data.properties

# %%
from pyterrier.measures import RR, nDCG, MAP

index = pt.IndexFactory.of(str(idx_path))

bm25 = pt.BatchRetrieve(index, wmodel="BM25")
rm3 = pt.rewrite.RM3(index)
testset = pt.get_dataset('irds:' + TESTSET_NAME)

# %%
from fast_forward.encoder import TCTColBERTQueryEncoder, TCTColBERTDocumentEncoder
import torch

q_encoder = TCTColBERTQueryEncoder("castorini/tct_colbert-msmarco")
d_encoder = TCTColBERTDocumentEncoder(
    "castorini/tct_colbert-msmarco",
    device="cuda:0" if torch.cuda.is_available() else "cpu",
)
q_encoder(["Test query 1", "Test query 2"])
# Out:
# array([[-0.0380525 ,  0.01848466,  0.05137944, ..., -0.04796502,
#          0.00918062, -0.03880693],
#        [-0.06809073,  0.02582865,  0.09803923, ..., -0.09031374,
#          0.00014139, -0.06282968]], dtype=float32)

# %%
from fast_forward import OnDiskIndex, Mode

ff_index = OnDiskIndex.load(
    Path(INDEX_PATH), query_encoder=q_encoder, mode=Mode.MAXP
)
ff_index = ff_index.to_memory()
# Out:
#   0%|          | 0/382545 [00:00<?, ?it/s]
# 100%|██████████| 382545/382545 [00:00<00:00, 1902895.45it/s]

# %%
from fast_forward.util.pyterrier import FFScore
from fast_forward.util.pyterrier import FFInterpolate

ff_score = FFScore(ff_index)
candidates = (bm25 % 5)(testset.get_topics('text')) # Get the candidates
re_ranked = ff_score(candidates)
ff_int = FFInterpolate(alpha=0.05)
ff_int(re_ranked)
# Out:
#     qid                                    docno  \
# 0     1  51530f3f-2019-04-18T18:15:02Z-00004-000
# 1     1  b0680508-2019-04-18T13:48:51Z-00002-000
# 2     1  c065954f-2019-04-18T14:32:52Z-00003-000
# 3     1  c065954f-2019-04-18T14:32:52Z-00001-000
# 4     1  ff0947ec-2019-04-18T12:23:12Z-00000-000
# ..   ..                                      ...
# 240  50  ffdf2e2e-2019-04-18T11:43:09Z-00005-000
# 241  50  b7051d6f-2019-04-18T11:25:14Z-00001-000
# 242  50  4d103793-2019-04-18T11:35:54Z-00007-000
# 243  50  4d103774-2019-04-18T13:49:55Z-00005-000
# 244  50  530b96d7-2019-04-18T11:55:04Z-00005-000
#
#                                             query      score
# 0                      should teachers get tenure  68.917621
# 1                      should teachers get tenure  68.690103
# 2                      should teachers get tenure  69.071692
# 3                      should teachers get tenure  68.714918
# 4                      should teachers get tenure  68.880417
# ..                                            ...        ...
# 240  should everyone get a universal basic income  67.569879
# 241  should everyone get a universal basic income  66.704010
# 242  should everyone get a universal basic income  67.924480
# 243  should everyone get a universal basic income  66.832887
# 244  should everyone get a universal basic income  66.773295
#
# [245 rows x 4 columns]

# %% [markdown]
# # Per Query Analysis

# %% [markdown]
# Run an experiment with the `perquery = True` flag to see individual query performance

# %%
result = pt.Experiment(
    [
        bm25 % 1000 >> ff_score >> ff_int,
        bm25 % 5 >> rm3 >> bm25 % 1000 >> pt.rewrite.reset() >> ff_score >> ff_int,
    ],
    testset.get_topics('text'),
    testset.get_qrels(),
    eval_metrics=[RR @ 10], # Use this for BEIR datasets
    # eval_metrics=[RR (rel = 2) @ 10], # Use this for TREC-DL datasets
    names=["TCT-ColBERT", "RM3+TCT-ColBERT"],
    perquery=True
)
result
# Out:
#                name qid measure  value
# 49  RM3+TCT-ColBERT   1   RR@10    1.0
# 50  RM3+TCT-ColBERT  10   RR@10    0.5
# 51  RM3+TCT-ColBERT  11   RR@10    1.0
# 52  RM3+TCT-ColBERT  12   RR@10    0.2
# 53  RM3+TCT-ColBERT  13   RR@10    1.0
# ..              ...  ..     ...    ...
# 48      TCT-ColBERT  50   RR@10    0.5
# 5       TCT-ColBERT   6   RR@10    1.0
# 6       TCT-ColBERT   7   RR@10    0.5
# 7       TCT-ColBERT   8   RR@10    0.0
# 8       TCT-ColBERT   9   RR@10    1.0
#
# [98 rows x 4 columns]

# %% [markdown]
# Group by the qid and calculate the Delta RR score, by which we sort to get the queries we are interested in

# %%
import pandas as pd

df = result
df['value'] = pd.to_numeric(result['value'])
df.groupby("qid")[['value']].apply(lambda g: g - g.iloc[0])
# Out:
#         value
# qid
# 1   49    0.0
#     0     0.0
# 10  50    0.0
#     9     0.0
# 11  51    0.0
# ...       ...
# 7   6     0.0
# 8   96    0.0
#     7     0.0
# 9   97    0.0
#     8     0.5
#
# [98 rows x 1 columns]

# %% [markdown]
# Select the query with the largest delta RR (lowest value in cell above)

# %%
REPRESENTATIVE_QUERY_ID = '5'
all_topics = testset.get_topics('text')
QUERY_SUBSET = all_topics[all_topics['qid'] == REPRESENTATIVE_QUERY_ID]
QUERY_SUBSET
# Out:
#   qid                                 query
# 4   5  should social security be privatized

# %% [markdown]
# Get the QRels from which we need to filter out the relevant document for our query

# %%
qrels = testset.get_qrels()
qrels[qrels['qid'] == REPRESENTATIVE_QUERY_ID]
# Out:
#     qid                                    docno  label iteration
# 179   5  fb9d1caa-2019-04-18T19:57:07Z-00003-000      0         0
# 180   5  f8a2755c-2019-04-18T14:34:51Z-00003-000      0         0
# 181   5  f898f8b6-2019-04-18T11:07:53Z-00001-000      0         0
# 182   5  ed146d2b-2019-04-18T18:30:30Z-00003-000      2         0
# 183   5  e28c98a3-2019-04-18T13:23:25Z-00005-000      2         0
# 184   5  cf4c9cbf-2019-04-17T11:47:24Z-00074-000      1         0
# 185   5  a7deb84a-2019-04-18T18:13:23Z-00000-000      0         0
# 186   5   adb11e8-2019-04-18T13:30:49Z-00001-000      0         0
# 187   5  cf4c9cbf-2019-04-17T11:47:24Z-00034-000      1         0
# 188   5  ccb2cd3b-2019-04-19T12:44:47Z-00002-000      0         0
# 189   5  ca713976-2019-04-18T12:06:48Z-00002-000      2         0
# 190   5  ca28d265-2019-04-18T15:02:57Z-00003-000      0         0
# 191   5  b4e53fbf-2019-04-18T12:06:48Z-00005-000      2         0
# 192   5  b2629620-2019-04-18T18:08:01Z-00003-000      0         0
# 193   5  68e62a4e-2019-04-18T13:14:27Z-00005-000      0         0
# 194   5  cf4c9cbf-2019-04-17T11:47:24Z-00067-000      1         0
# 195   5  96775ff7-2019-04-18T17:01:41Z-00000-000      0         0
# 196   5  21579906-2019-04-15T20:22:50Z-00009-000      0         0
# 197   5  94c2b13e-2019-04-18T12:39:12Z-00005-000      1         0
# 198   5  8ecb5e60-2019-04-18T18:47:07Z-00005-000      0         0
# 199   5  8c527667-2019-04-18T19:32:56Z-00003-000      2         0
# 200   5  8c527667-2019-04-18T19:32:56Z-00002-000      0         0
# 201   5  8c527629-2019-04-18T19:33:00Z-00000-000      0         0
# 202   5  8c527629-2019-04-18T19:33:00Z-00002-000      2         0
# 203   5  8c527629-2019-04-18T19:33:00Z-00003-000      2         0
# 204   5  88df2c79-2019-04-18T15:49:36Z-00000-000      0         0
# 205   5  7af08047-2019-04-18T17:37:15Z-00005-000      0         0
# 206   5  785830f5-2019-04-18T12:06:37Z-00001-000      0         0
# 207   5  68faa15f-2019-04-18T16:49:59Z-00004-000      0         0
# 208   5  cf4c9cbf-2019-04-17T11:47:24Z-00000-000      0         0
# 209   5  5f3eab31-2019-04-18T12:44:43Z-00001-000      0         0
# 210   5  5662e460-2019-04-18T18:54:15Z-00005-000      0         0
# 211   5  458224f5-2019-04-18T16:08:47Z-00003-000      0         0
# 212   5  62ac1cd7-2019-04-18T16:11:18Z-00001-000      0         0
# 213   5  38b0fe14-2019-04-18T12:54:22Z-00005-000      2         0
# 214   5  2476225d-2019-04-18T14:28:24Z-00007-000      0         0
# 215   5  260780d5-2019-04-18T15:27:35Z-00005-000      0         0
# 216   5  41247294-2019-04-18T18:34:58Z-00002-000      0         0
# 217   5  2d6f4e75-2019-04-15T20:22:43Z-00013-000      2         0
# 218   5  2d6f4e75-2019-04-15T20:22:43Z-00009-000      2         0
# 219   5  2d6f4e75-2019-04-15T20:22:43Z-00000-000      0         0
# 220   5  2d6f4e75-2019-04-15T20:22:43Z-00007-000      2         0
# 221   5  36edcc1c-2019-04-18T19:45:50Z-00001-000      0         0
# 222   5  36edcc1c-2019-04-18T19:45:50Z-00000-000      0         0
# 223   5  38b0fdf5-2019-04-18T12:55:15Z-00001-000      2         0
# 224   5  38b0fdf5-2019-04-18T12:55:15Z-00005-000      0         0
# 225   5  2f5384a7-2019-04-18T18:11:33Z-00001-000      0         0

# %% [markdown]
# Verify Delta RR corresponds

# %%
pt.Experiment(
    [
        bm25 % 1000 >> ff_score >> ff_int,
        bm25 % 5 >> rm3 >> bm25 % 1000 >> pt.rewrite.reset() >> ff_score >> ff_int,
    ],
    QUERY_SUBSET,
    testset.get_qrels(),
    eval_metrics=[RR @ 10], # Use this for BEIR datasets
    # eval_metrics=[RR (rel = 2) @ 10], # Use this for TREC-DL datasets
    names=["TCT-ColBERT", "RM3+TCT-ColBERT"],
    perquery=True
)
# Out:
#               name qid measure  value
# 1  RM3+TCT-ColBERT   5   RR@10    1.0
# 0      TCT-ColBERT   5   RR@10    0.5

# %% [markdown]
# See ranking for RM3+TCT-ColBERT

# %%
df = (bm25 % 5 >> rm3 >> bm25 % 1000 >> pt.rewrite.reset() >> ff_score >> ff_int)(QUERY_SUBSET)
df[df['qid'] == REPRESENTATIVE_QUERY_ID]
# Out:
#     qid                                    docno  \
# 0     5  cf4c9cbf-2019-04-17T11:47:24Z-00055-000
# 1     5  2d6f4e75-2019-04-15T20:22:43Z-00009-000
# 2     5  2d6f4e75-2019-04-15T20:22:43Z-00007-000
# 3     5  dac7811d-2019-04-18T20:00:32Z-00001-000
# 4     5  cf4c9cbf-2019-04-17T11:47:24Z-00062-000
# ..   ..                                      ...
# 995   5  f12999ea-2019-04-18T15:44:02Z-00005-000
# 996   5  1e31a0c1-2019-04-18T20:00:01Z-00003-000
# 997   5  319205df-2019-04-15T20:23:04Z-00007-000
# 998   5  7d47f8ba-2019-04-18T19:36:54Z-00004-000
# 999   5   8685458-2019-04-18T17:08:31Z-00000-000
#
#                                     query      score
# 0    should social security be privatized  67.410446
# 1    should social security be privatized  67.025839
# 2    should social security be privatized  67.664482
# 3    should social security be privatized  66.345922
# 4    should social security be privatized  67.406605
# ..                                    ...        ...
# 995  should social security be privatized  63.437451
# 996  should social security be privatized  64.900629
# 997  should social security be privatized  63.765195
# 998  should social security be privatized  64.065127
# 999  should social security be privatized  63.453860
#
# [1000 rows x 4 columns]

# %% [markdown]
# See ranking for TCT-ColBERT

# %%
df2 = (bm25 % 1000 >> ff_score >> ff_int)(QUERY_SUBSET)
df2[df2['qid'] == REPRESENTATIVE_QUERY_ID]
# Out:
#     qid                                    docno  \
# 0     5  2d6f4e75-2019-04-15T20:22:43Z-00009-000
# 1     5  cf4c9cbf-2019-04-17T11:47:24Z-00055-000
# 2     5  2d6f4e75-2019-04-15T20:22:43Z-00007-000
# 3     5  cf4c9cbf-2019-04-17T11:47:24Z-00062-000
# 4     5  2d6f4e75-2019-04-15T20:22:43Z-00015-000
# ..   ..                                      ...
# 995   5  dd3769ca-2019-04-18T19:44:34Z-00002-000
# 996   5  d8d74905-2019-04-18T15:19:51Z-00002-000
# 997   5  ab490cb9-2019-04-18T19:45:33Z-00003-000
# 998   5  ae43584a-2019-04-18T12:49:12Z-00000-000
# 999   5  7a47e0cb-2019-04-18T17:33:08Z-00003-000
#
#                                     query      score
# 0    should social security be privatized  66.802201
# 1    should social security be privatized  67.119543
# 2    should social security be privatized  67.543852
# 3    should social security be privatized  67.329656
# 4    should social security be privatized  66.796272
# ..                                    ...        ...
# 995  should social security be privatized  63.296032
# 996  should social security be privatized  63.953152
# 997  should social security be privatized  64.769290
# 998  should social security be privatized  63.262071
# 999  should social security be privatized  63.746564
#
# [1000 rows x 4 columns]

# %% [markdown]
# Inspect how the query is expanded:

# %%
df3 = (bm25 % 5 >> rm3 >> bm25 % 100)(testset.get_topics('text'))
df3[df3['qid'] == REPRESENTATIVE_QUERY_ID]
# Out:
#       qid   docid                                    docno  rank      score  \
# 43000   5  370977  cf4c9cbf-2019-04-17T11:47:24Z-00055-000     0  32.324364
# 43001   5  334864  2d6f4e75-2019-04-15T20:22:43Z-00009-000     1  31.137817
# 43002   5  334863  2d6f4e75-2019-04-15T20:22:43Z-00007-000     2  28.741153
# 43003   5  281446  dac7811d-2019-04-18T20:00:32Z-00001-000     3  28.247629
# 43004   5  370971  cf4c9cbf-2019-04-17T11:47:24Z-00062-000     4  27.468185
# ...    ..     ...                                      ...   ...        ...
# 43095   5  307560  8c527629-2019-04-18T19:33:00Z-00003-000    95  20.258738
# 43096   5  187761   988cf27-2019-04-18T12:54:20Z-00004-000    96  20.243477
# 43097   5   20314  969c1d86-2019-04-18T18:25:10Z-00002-000    97  20.154339
# 43098   5  242953  effbd50f-2019-04-18T17:55:11Z-00005-000    98  20.137370
# 43099   5  370982  cf4c9cbf-2019-04-17T11:47:24Z-00063-000    99  20.086005
#
#                                     query_0  \
# 43000  should social security be privatized
# 43001  should social security be privatized
# 43002  should social security be privatized
# 43003  should social security be privatized
# 43004  should social security be privatized
# ...                                     ...
# 43095  should social security be privatized
# 43096  should social security be privatized
# 43097  should social security be privatized
# 43098  should social security be privatized
# 43099  should social security be privatized
#
#                                                                                                                                                                                                               query
# 43000  applypipeline:off social^0.280862361 invest^0.016216118 privat^0.260482877 elderli^0.031810354 benefit^0.026657782 system^0.015973436 secur^0.279393673 poor^0.045462392 retir^0.020409806 incom^0.022731196
# 43001  applypipeline:off social^0.280862361 invest^0.016216118 privat^0.260482877 elderli^0.031810354 benefit^0.026657782 system^0.015973436 secur^0.279393673 poor^0.045462392 retir^0.020409806 incom^0.022731196
# 43002  applypipeline:off social^0.280862361 invest^0.016216118 privat^0.260482877 elderli^0.031810354 benefit^0.026657782 system^0.015973436 secur^0.279393673 poor^0.045462392 retir^0.020409806 incom^0.022731196
# 43003  applypipeline:off social^0.280862361 invest^0.016216118 privat^0.260482877 elderli^0.031810354 benefit^0.026657782 system^0.015973436 secur^0.279393673 poor^0.045462392 retir^0.020409806 incom^0.022731196
# 43004  applypipeline:off social^0.280862361 invest^0.016216118 privat^0.260482877 elderli^0.031810354 benefit^0.026657782 system^0.015973436 secur^0.279393673 poor^0.045462392 retir^0.020409806 incom^0.022731196
# ...                                                                                                                                                                                                             ...
# 43095  applypipeline:off social^0.280862361 invest^0.016216118 privat^0.260482877 elderli^0.031810354 benefit^0.026657782 system^0.015973436 secur^0.279393673 poor^0.045462392 retir^0.020409806 incom^0.022731196
# 43096  applypipeline:off social^0.280862361 invest^0.016216118 privat^0.260482877 elderli^0.031810354 benefit^0.026657782 system^0.015973436 secur^0.279393673 poor^0.045462392 retir^0.020409806 incom^0.022731196
# 43097  applypipeline:off social^0.280862361 invest^0.016216118 privat^0.260482877 elderli^0.031810354 benefit^0.026657782 system^0.015973436 secur^0.279393673 poor^0.045462392 retir^0.020409806 incom^0.022731196
# 43098  applypipeline:off social^0.280862361 invest^0.016216118 privat^0.260482877 elderli^0.031810354 benefit^0.026657782 system^0.015973436 secur^0.279393673 poor^0.045462392 retir^0.020409806 incom^0.022731196
# 43099  applypipeline:off social^0.280862361 invest^0.016216118 privat^0.260482877 elderli^0.031810354 benefit^0.026657782 system^0.015973436 secur^0.279393673 poor^0.045462392 retir^0.020409806 incom^0.022731196
#
# [100 rows x 7 columns]

# %% [markdown]
# See ranking for BM25

# %%
df4 = (bm25 % 100)(testset.get_topics('text'))
df4[df4['qid'] == REPRESENTATIVE_QUERY_ID]
# Out:
#      qid   docid                                    docno  rank      score  \
# 4000   5  334864  2d6f4e75-2019-04-15T20:22:43Z-00009-000     0  26.665043
# 4001   5  370977  cf4c9cbf-2019-04-17T11:47:24Z-00055-000     1  26.506306
# 4002   5  334863  2d6f4e75-2019-04-15T20:22:43Z-00007-000     2  26.328549
# 4003   5  370971  cf4c9cbf-2019-04-17T11:47:24Z-00062-000     3  25.929203
# 4004   5  334867  2d6f4e75-2019-04-15T20:22:43Z-00015-000     4  25.403738
# ...   ..     ...                                      ...   ...        ...
# 4095   5  266819  c61cb529-2019-04-18T19:57:16Z-00002-000    95  19.168881
# 4096   5  309353  38b0fdf5-2019-04-18T12:55:15Z-00004-000    96  19.157993
# 4097   5  233198  8270f66a-2019-04-18T11:46:47Z-00005-000    97  19.118600
# 4098   5  305442  4809e6cc-2019-04-18T13:30:35Z-00003-000    98  19.084106
# 4099   5  370988  cf4c9cbf-2019-04-17T11:47:24Z-00056-000    99  19.082329
#
#                                      query
# 4000  should social security be privatized
# 4001  should social security be privatized
# 4002  should social security be privatized
# 4003  should social security be privatized
# 4004  should social security be privatized
# ...                                    ...
# 4095  should social security be privatized
# 4096  should social security be privatized
# 4097  should social security be privatized
# 4098  should social security be privatized
# 4099  should social security be privatized
#
# [100 rows x 6 columns]

# %% [markdown]
# Find the document(s) we are interested in

# %%
for q in ir_ds.docs_iter():
    if q.doc_id not in ['2d6f4e75-2019-04-15T20:22:43Z-00007-000']:
        continue
    print(q.text)
    print("Document ID:" + q.doc_id)
    print("---------------")
# Out:
# Privatizing social security would enable investment of savings. Commentator Alex Schibuola argues that: "If Social Security were privatized, people would deposit their income with a bank. People actually save resources that businesses can invest. We, as true savers, get more resources in the future."[1]  As a result private accounts would also increase investments, jobs and wages. Michael Tanner of the think tank the Cato Institute argues: "Social Security drains capital from the poorest areas of the country, leaving less money available for new investment and job creation. Privatization would increase national savings and provide a new pool of capital for investment that would be particularly beneficial to the poor."[2] Currently Social Security represents a net loss for taxpayers and beneficiaries. Social Security, although key to the restructuring the of USA’s social contract following the great depression, represents a bad deal for the post-war American economy. Moreover, this deal has gotten worse over time. 'Baby boomers' are projected to lose roughly 5 cents of every dollar they earn to the OASI program in taxes net of benefits. Young adults who came of age in the early 1990s and today's children are on course to lose over 7 cents of every dollar they earn in net taxes. If OASI taxes were to be raised immediately by the amount needed to pay for OASI benefits on an on-going basis, baby boomers would forfeit 6 cents of every dollar they earn in net OASI taxes. For those born later it would be 10 cents.[3] Change could be implemented gradually. Andrew Roth argues: “While Americans in retirement or approaching retirement would probably stay in the current system [if Social Security were to be privatized], younger workers should have the option to invest a portion of their money in financial assets other than U.S. Treasuries. These accounts would be the ultimate "lock box" - they would prevent politicians in Washington from raiding the Trust Fund. The truth is that taxpayers bail out politicians every year thanks to Social Security. Congress and the White House spend more money than they have, so they steal money from Social Security to help pay for it. That needs to stop and there is no responsible way of doing that except with personal accounts.”[4] This would make social security much more sustainable as there would no longer be the risk of the money being spent elsewhere. Put simply, privatizing Social Security would actually boost economic growth and lead to better-protected investments by beneficiaries, benefiting not only themselves but the nation at large. Thus Social Security should be privatized. [1] Schibuola, Alex. "Time to Privatize? The Economics of Social Security." Open Markets. 16 November 2010. http://www.openmarket.org/2010/11/16/time-to-privatize-the-economics-of-... [2] Tanner, Michael. "Privatizing Social Security: A Big Boost for the Poor." CATO. 26 July 1996. http://www.socialsecurity.org/pubs/ssps/ssp4.html [3] Kotlikoff, Lawrence. "Privatizing social security the right way". Testimony to the Committee on Ways and Means. 3 June 3 1998. http://people.bu.edu/kotlikof/Ways&Means.pdf [4] Roth, Andrew. "Privatize Social Security? Hell Yeah!". Club for Growth.21  September 21 2010. http://www.clubforgrowth.org/perm/?
# Document ID:2d6f4e75-2019-04-15T20:22:43Z-00007-000
# ---------------
